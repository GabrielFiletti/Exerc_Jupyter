# %% [markdown]
# # Tutorial FIEP Gabriel

# %% [markdown]
# ## Exibição de lista

# %%
lista = [1, 2, 5]
print (lista)
# Out:
# [1, 2, 5]

# %% [markdown]
# ![salt](https://s17-us2.startpage.com/cgi-bin/serveimage?url=https%3A%2F%2Fthenypost.files.wordpress.com%2F2019%2F01%2Fsalt-bae-swiped-our-tips-then-fired-us-for-complaining.jpg%3Fquality%3D90%26strip%3Dall%26w%3D618%26h%3D410%26crop%3D1&sp=5f429d638275d08929250e1ebaca6f88&anticache=631068)

# %%
print(lista, cont)
# Out:
# [1, 2, 5] 100

# %%
# !pwd
# Out:
# /home/gabrielmartins

# %%
# !uptime
# Out:
#  15:42:25 up  2:45,  1 user,  load average: 1,43, 1,13, 1,01

# %%
from math import *
a=10
b=20
print(sqrt(a*b))
# Out:
# 14.142135623730951

# %%
cont = 100

# %%
print(cont)
# Out:
# 100

# %% [markdown]
# ## Comandos do sistema

# %%
# !ls
# Out:
# 'Área de Trabalho'	     ex2.yml		 Música
# 'Atividade 1 - 02-out.odt'   examples.desktop	 newenv.yml
# 'Atividade 2 - 03-out.odt'  'Exercícios 1.odt'	 Público
#  cuda-workspace		     Imagens		 snap
#  Documentos		     miniconda3		'Teste FIEP Gabriel.ipynb'
#  Downloads		     Modelos		 Vídeos

# %%
# !top
# Out:
# =top - 15:54:09 up  2:56,  1 user,  load average: 1,33, 1,10, 1,07
# Tarefas: 303 total,   2 em exec., 222 dormindo,   0 parado,   0 zumbi
# %CPU(s):  6,4 us,  2,7 sis,  0,0 ni, 88,9 oc,  0,6 ag,  0,0 ih,  1,4 is  0,0 tr
# KB mem : 16223748 total,  9325144 livre,  3228172 usados,  3670432 buff/cache
# KB swap:  2097148 total,  2097148 livre,        0 usados, 12577304 mem dispon.
#
#   PID USUARIO   PR  NI    VIRT    RES    SHR S  %CPU %MEM    TEMPO+ COMANDO
#  2674 gabriel+  20   0 6543800 1,014g 200184 S  38,9  6,6 106:28.38 zoom
#  1380 gabriel+   9 -11 1959652  15300  11456 R  27,8  0,1  41:09.91 pulseaudio
#  1353 gabriel+  20   0 4705960 492072 107236 S  16,7  3,0  19:28.61 gnome-shell
# 13670 gabriel+  20   0  918552 196204  88584 S  16,7  1,2   1:33.38 chrome
# 14029 gabriel+  20   0   51572   4208   3456 R  16,7  0,0   0:00.05 top
#  3876 gabriel+  20   0  714548 213112 103844 S  11,1  1,3   3:23.95 chrome
# ...

# %%
# !ls
